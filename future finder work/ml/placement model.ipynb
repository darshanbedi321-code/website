# %%
# importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing a dataset and storing in variable df
df = pd.read_csv(r'C:\Users\darsh_3lhmtua\pythone start\future finder work\csv\placement.csv')

# %%
# showing data set
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# cleaning dataset by removing unwanted coloumns for df
df= df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# ploting graph(data visualition)
plt.scatter(df['cgpa'],df['iq'],c = df['placement'] )

# %%
# seperating input and out put columns
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
# importing ml library and spliting data 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 51   4.8  141.0
# 81   5.4  107.0
# 98   6.3  103.0
# 4    5.8  142.0
# 99   6.2  113.0
# ..   ...    ...
# 41   5.4  114.0
# 7    5.0   63.0
# 67   5.0  118.0
# 70   6.3  127.0
# 13   6.4  116.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 66   6.9   96.0
# 97   6.7  182.0
# 94   4.7   52.0
# 3    7.4  132.0
# 83   7.5  130.0
# 19   5.2  132.0
# 85   5.8  166.0
# 65   8.1  166.0
# 12   5.4  139.0
# 5    7.1   48.0

# %%
y_train
# Out:
# 51    0
# 81    0
# 98    1
# 4     0
# 99    1
#      ..
# 41    0
# 7     0
# 67    0
# 70    1
# 13    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 66    1
# 97    1
# 94    0
# 3     1
# 83    1
# 19    0
# 85    1
# 65    1
# 12    0
# 5     1
# Name: placement, dtype: int64

# %%
# importing ml library for scaling large values of data in smaller values
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
x_train = scale.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.00438014,  0.44541376],
#        [-0.4742088 , -0.41996155],
#        [ 0.3210482 , -0.52177041],
#        [-0.12076125,  0.47086598],
#        [ 0.23268631, -0.26724826],
#        [-0.91601825,  0.80174477],
#        [ 1.64647653, -0.24179604],
#        [-0.65093258,  2.5579476 ],
#        [ 0.93958142,  0.39450933],
#        [-0.91601825,  1.84528558],
#        [-0.73929447,  0.11453497],
#        [ 0.67449575,  0.77629255],
#        [ 1.46975275,  0.11453497],
#        [ 0.14432442, -0.52177041],
#        [-0.65093258, -0.3436049 ],
#        [-0.91601825, -1.59076343],
#        [ 0.93958142, -1.51440679],
#        [-1.09274203, -0.06363054],
#        [-0.91601825,  0.69993591],
#        [-0.20912314,  0.21634383],
#        [-1.00438014,  1.15807578],
#        [ 1.46975275, -0.87810141],
#        [-1.79963714, -0.36905712],
#        [ 0.49777198,  0.1654394 ],
#        [ 0.76285764,  0.44541376],
#        [-0.91601825, -0.08908275],
#        [ 0.05596253, -0.54722262],
# ...

# %%
x_test = scale.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.85121953, -0.69993591],
#        [ 0.67449575,  1.48895457],
#        [-1.09274203, -1.81983337],
#        [ 1.29302898,  0.21634383],
#        [ 1.38139087,  0.1654394 ],
#        [-0.65093258,  0.21634383],
#        [-0.12076125,  1.08171913],
#        [ 1.9115622 ,  1.08171913],
#        [-0.4742088 ,  0.39450933],
#        [ 1.02794331, -1.92164222]])

# %%
# importing logistic regression model 
from sklearn.linear_model import LogisticRegression

# %%
# storing model in variable clf
clf = LogisticRegression()

# %%
# training the model
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# /model testing and storing out put in varible y_predict
y_pred = clf.predict(x_test)

# %% [markdown]
# displaying predictions and expected outputs

# %%
y_pred
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 1, 0, 1])

# %%
y_test
# Out:
# 66    1
# 97    1
# 94    0
# 3     1
# 83    1
# 19    0
# 85    1
# 65    1
# 12    0
# 5     1
# Name: placement, dtype: int64

# %%
# importing library for calculating accuracy
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
#ploting
from mlxtend.plotting import plot_decision_regions

# x_train is a 2D array and y_train.values provides labels as an array
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
# storing model in a file
import pickle
pickle.dump(clf,open('model.pkl','wb'))
