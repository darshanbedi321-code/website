# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica

# %%
sns.lineplot(x= "sepal_length",y = "sepal_width",data= df , label= "sepal",hue= "species")
sns.lineplot(x= "petal_length",y = "petal_width",data= df, label= "petal",hue= "species")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.lineplot(x= "sepal_length",y = "sepal_width",data= df , label= "sepal",hue= "species")
#       2 sns.lineplot(x= "petal_length",y = "petal_width",data= df, label= "petal",hue= "species")
#
# File c:\Users\darsh_3lhmtua\anaconda3\Lib\site-packages\seaborn\relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# ...

# %%
sns.barplot(x="species",y="petal_length",data=df,hue= "species")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.scatterplot(x= "sepal_length",y = "sepal_width",data= df , label= "sepal",hue= "species")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.scatterplot(x= "sepal_length",y = "sepal_width",data= df , label= "sepal",hue= "species")
#
# File c:\Users\darsh_3lhmtua\anaconda3\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\darsh_3lhmtua\anaconda3\Lib\site-packages\seaborn\relational.py:464, in _ScatterPlotter.plot(self, ax, kws)
#     462 if self.legend:
#     463     attrs = {"hue": "color", "size": "s", "style": None}
# --> 464     self.add_legend_data(ax, _scatter_legend_artist, kws, attrs)
# ...

# %%
sns.scatterplot(x= "petal_length",y = "petal_width",data= df,hue= "species")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.histplot(x="petal_length",data= df, label= "petal",hue= "species")
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(x="sepal_length",data= df,kde= True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(x="sepal_length",data= df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.boxplot(x="sepal_length",data= df)
# Out:
# <Axes: xlabel='sepal_length'>

# %%
sns.boxplot(x="sepal_width",data= df)
# Out:
# <Axes: xlabel='sepal_width'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
C= df.corr(numeric_only=True)

# %%
C
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(C,annot= True)
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue= "species")
plt.savefig("graph")

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2=df.groupby("species")["sepal_width"].mean()

# %%
df2
# Out:
# species
# setosa        3.428
# versicolor    2.770
# virginica     2.974
# Name: sepal_width, dtype: float64

# %%
plt.pie(df2.values,labels= df2.index,autopct= "%1.2f%%")
plt.savefig("pie.png")
plt.show()

# %%
sns.countplot(x= "species",data= df)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\darsh_3lhmtua\pythone start\csv\car_price.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             5512 non-null   object
#  1   car_prices_in_rupee  5512 non-null   object
#  2   kms_driven           5511 non-null   object
#  3   fuel_type            5510 non-null   object
#  4   transmission         5511 non-null   object
#  5   ownership            5509 non-null   object
#  6   manufacture          5507 non-null   float64
#  7   engine               5511 non-null   object
#  8   Seats                5511 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 387.7+ KB

# %%
df.columns
# Out:
# Index(['car_name', 'car_prices_in_rupee', 'kms_driven', 'fuel_type',
#        'transmission', 'ownership', 'manufacture', 'engine', 'Seats'],
#       dtype='object')

# %%
df.shape
# Out:
# (5512, 9)

# %%
df.dtypes
# Out:
# car_name                object
# car_prices_in_rupee     object
# kms_driven              object
# fuel_type               object
# transmission            object
# ownership               object
# manufacture            float64
# engine                  object
# Seats                   object
# dtype: object

# %%
df.head()
# Out:
#                                  car_name car_prices_in_rupee  kms_driven  \
# 0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1            Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                      Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                       Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
#
#   fuel_type transmission  ownership  manufacture   engine    Seats
# 0    Diesel       Manual  1st Owner       2017.0  1956 cc  5 Seats
# 1    Petrol    Automatic  1st Owner       2021.0  1330 cc  5 Seats
# 2    Petrol    Automatic  1st Owner       2016.0  2494 cc  5 Seats
# 3    Petrol    Automatic  1st Owner       2018.0  1199 cc  5 Seats
# 4    Petrol       Manual  1st Owner       2016.0      NaN  5 Seats

# %%
df.isnull().sum()
# Out:
# car_name               0
# car_prices_in_rupee    0
# kms_driven             1
# fuel_type              2
# transmission           1
# ownership              3
# manufacture            5
# engine                 1
# Seats                  1
# dtype: int64

# %%
df.dropna()
# Out:
#                                     car_name car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1               Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                         Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                          Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 5                                 Volkswagen           7.66 Lakh  49,719 kms
# ...                                      ...                 ...         ...
# 5507                 BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508                   BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510                      BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511               BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
# ...

# %%
df.fillna(df.mean(numeric_only=True))
df.drop(columns=["fuel_type","transmission",""])
# Out:
#                                     car_name car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1               Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                         Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                          Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4           Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
# ...                                      ...                 ...         ...
# 5507                 BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508                   BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510                      BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511               BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(76)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#        manufacture
# count  5431.000000
# mean   2015.436936
# std       3.939369
# min    1995.000000
# 25%    2013.000000
# 50%    2016.000000
# 75%    2018.000000
# max    2022.000000

# %%
import seaborn as sns

# %%
sns.boxplot(x=df["manufacture"])
# Out:
# <Axes: xlabel='manufacture'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.heatmap(df.corr(),annot=True)
#
# File c:\Users\darsh_3lhmtua\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\darsh_3lhmtua\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...
